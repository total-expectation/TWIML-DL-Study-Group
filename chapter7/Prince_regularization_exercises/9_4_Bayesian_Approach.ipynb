# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap09/9_4_Bayesian_Approach.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 9.4: Bayesian approach**
#
# This notebook investigates the Bayesian approach to model fitting and reproduces figure 9.11 from the book.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
# Define seed so get same results each time
np.random.seed(1)

# %%
# The true function that we are trying to estimate, defined on [0,1]
def true_function(x):
    y = np.exp(np.sin(x*(2*3.1413)))
    return y

# %%
# Generate some data points with or without noise
def generate_data(n_data, sigma_y=0.3):
    # Generate x values quasi uniformly
    x = np.ones(n_data)
    for i in range(n_data):
        x[i] = np.random.uniform(i/n_data, (i+1)/n_data, 1)

    # y value from running through function and adding noise
    y = np.ones(n_data)
    for i in range(n_data):
        y[i] = true_function(x[i])
        y[i] += np.random.normal(0, sigma_y, 1)
    return x,y

# %%
# Draw the fitted function, together win uncertainty used to generate points
def plot_function(x_func, y_func, x_data=None,y_data=None, x_model = None, y_model =None, sigma_func = None, sigma_model=None):

    fig,ax = plt.subplots()
    ax.plot(x_func, y_func, 'k-')
    if sigma_func is not None:
      ax.fill_between(x_func, y_func-2*sigma_func, y_func+2*sigma_func, color='lightgray')

    if x_data is not None:
        ax.plot(x_data, y_data, 'o', color='#d18362')

    if x_model is not None:
        ax.plot(x_model, y_model, '-', color='#7fe7de')

    if sigma_model is not None:
      ax.fill_between(x_model, y_model-2*sigma_model, y_model+2*sigma_model, color='lightgray')

    ax.set_xlim(0,1)
    ax.set_xlabel('Input, $x$')
    ax.set_ylabel('Output, $y$')
    plt.show()

# %%
# Generate true function
x_func = np.linspace(0, 1.0, 100)
y_func = true_function(x_func);

# Generate some data points
np.random.seed(1)
sigma_func = 0.3
n_data = 15
x_data,y_data = generate_data(n_data, sigma_func)

# Plot the function, data and uncertainty
plot_function(x_func, y_func, x_data, y_data, sigma_func=sigma_func)
# Out:
# C:\Users\harry\AppData\Local\Temp\ipykernel_10008\2000407647.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x[i] = np.random.uniform(i/n_data, (i+1)/n_data, 1)
# C:\Users\harry\AppData\Local\Temp\ipykernel_10008\2000407647.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i] += np.random.normal(0, sigma_y, 1)

# %%
# Define model -- beta is a scalar and omega has size n_hidden,1
def network(x, beta, omega):
    # Retrieve number of hidden units
    n_hidden = omega.shape[0]

    y = np.zeros_like(x)
    for c_hidden in range(n_hidden):
        # Evaluate activations based on shifted lines (figure 8.4b-d)
        line_vals =  x  - c_hidden/n_hidden
        h =  line_vals * (line_vals > 0)
        # Weight activations by omega parameters and sum
        y = y + omega[c_hidden] * h
    # Add bias, beta
    y = y + beta

    return y

# %% [markdown]
# Now let's compute a probability distribution over the model parameters using Bayes's rule:
#
# \begin{equation}
#  Pr(\boldsymbol\phi|\{\mathbf{x}_{i},\mathbf{y}_{i}\}) = \frac{\prod_{i=1}^{I} Pr(\mathbf{y}_{i}|\mathbf{x}_{i},\boldsymbol\phi) Pr(\boldsymbol\phi)}{\int \prod_{i=1}^{I} Pr(\mathbf{y}_{i}|\mathbf{x}_{i},\boldsymbol\phi) Pr(\boldsymbol\phi)d\boldsymbol\phi } ,
# \end{equation}
#
# We'll define the prior $Pr(\boldsymbol\phi)$ as:
#
# \begin{equation}
# Pr(\boldsymbol\phi) = \text{Norm}_{\boldsymbol\phi}\bigl[\mathbf{0},\sigma^2_p\mathbf{I}\bigr]
# \end{equation}
#
# where $\phi=[\omega_1,\omega_2\ldots \omega_n, \beta]^T$ and $\sigma^2_{p}$  is the prior variance.
#
# The likelihood term $\prod_{i=1}^{I} Pr(\mathbf{y}_{i}|\mathbf{x}_{i},\boldsymbol\phi)$ is given by:
#
# \begin{align}
# \prod_{i=1}^{I} Pr(\mathbf{y}_{i}|\mathbf{x}_{i},\boldsymbol\phi) &=& \prod_{i=1}^{I} \text{Norm}_{y_i}\bigl[\text{f}[\mathbf{x}_{i},\boldsymbol\phi],\sigma_d^2\bigr]\\
# &=& \prod_{i=1}^{I} \text{Norm}_{y_i}\bigl[\boldsymbol\omega\mathbf{h}_i+\beta,\sigma_d^2\bigr]\\
# &=& \text{Norm}_{\mathbf{y}}\bigl[\mathbf{H}^T\boldsymbol\phi,\sigma^2\mathbf{I}\bigr].
# \end{align}
#
# where $\sigma^2$ is the measurement noise and $\mathbf{h}_{i}$ is the column vector of hidden variables for the $i^{th}$ input.  Here the vector $\mathbf{y}$ and matrix $\mathbf{H}$ are defined as:
#
# \begin{equation}
# \mathbf{y} = \begin{bmatrix}y_1\\y_2\\\vdots\\y_{I}\end{bmatrix}\quad\text{and}\quad \mathbf{H} = \begin{bmatrix}\mathbf{h}_{1}&\mathbf{h}_{2}&\cdots&\mathbf{h}_{I}\\1&1&\cdots &1\end{bmatrix}.
# \end{equation}
#
# <div style="color:green">
#
# Equation 2 and 3 confused me greatly as I didn't know whether to interpret the $\omega$ as a vector or matrix and the dimensionality on it seemed a bit off regardless. Turns out it's a vector
#
# $$\omega = \begin{bmatrix}\omega_1\\\omega_2\\\vdots\\\omega_n\end{bmatrix}$$
#
# as I assume all vectors are column vectors by default, which feels like it's the case both in the book and the programming exercises unless stated otherwise. This means that under this assumption eq 2 needs to transpose $\omega$ in order to carry out the dot product between $\omega$ and $h_i$, meaning $\omega^T h_i$.
#
# Dimension clarifications:
# - H is size $(n+1) \times I$
# - $\omega$ is size $n \times 1$
# - $h_i$ is size $n \times 1$
# - $\phi$ is size $(n+1) \times 1$
# - $\beta$ is scalar
#
# Furthermore to give context on what the likelihood looks like if expressed non-probabilistically:
#
# $$
# y_i = (w^T h_i + \beta) + \epsilon ,\  \epsilon \sim \mathcal{N}(0, \sigma^2 I)
# $$
#
# This makes it clearer how the multivariate gaussian is related to the outputs of the model prediction $f(x_i, \phi) = \omega^T h_i + \beta$, meaning it's just the mean of the multivariate gaussian, while the noise $\epsilon$ is an isotropic multivariate guassian distributed (0 mean and constant variance but zero covariance and thus a diagonal covariance matrix) random variable.
# </div>

# %% [markdown]
# To make progress we use the change of variable relation (Appendix C.3.4 of the book) to rewrite the likelihood term as a normal distribution in the parameters $\boldsymbol\phi$:
#
# \begin{align}
# \prod_{i=1}^{I} Pr(\mathbf{y}_{i}|\mathbf{x}_{i},\boldsymbol\phi+\beta)
# &=& \text{Norm}_{\mathbf{y}}\bigl[\mathbf{H}^T\boldsymbol\phi,\sigma^2\bigr]\\
# &\propto& \text{Norm}_{\boldsymbol\phi}\bigl[(\mathbf{H}\mathbf{H}^T)^{-1}\mathbf{H}\mathbf{y},\sigma^2(\mathbf{H}\mathbf{H}^t)^{-1}\bigr]
# \end{align}

# %% [markdown]
# Finally, we can combine the likelihood and prior terms using the product of two normal distributions relation (Appendix C.3.3).
#
# \begin{align}
#  Pr(\boldsymbol\phi|\{\mathbf{x}_{i},\mathbf{y}_{i}\}) &\propto& \prod_{i=1}^{I} Pr(\mathbf{y}_{i}|\mathbf{x}_{i},\boldsymbol\phi) Pr(\boldsymbol\phi)\\
#  &\propto&\text{Norm}_{\boldsymbol\phi}\bigl[(\mathbf{H}\mathbf{H}^T)^{-1}\mathbf{H}\mathbf{y},\sigma^2(\mathbf{H}\mathbf{H}^T)^{-1}\bigr] \text{Norm}_{\boldsymbol\phi}\bigl[\mathbf{0},\sigma^2_p\mathbf{I}\bigr]\\
#  &\propto&\text{Norm}_{\boldsymbol\phi}\biggl[\frac{1}{\sigma^2}\left(\frac{1}{\sigma^2}\mathbf{H}\mathbf{H}^T+\frac{1}{\sigma_p^2}\mathbf{I}\right)^{-1}\mathbf{H}\mathbf{y},\left(\frac{1}{\sigma^2}\mathbf{H}\mathbf{H}^T+\frac{1}{\sigma_p^2}\mathbf{I}\right)^{-1}\biggr].
# \end{align}
#
# In fact, since this already a normal distribution, the constant of proportionality must be one and we can write
#
# \begin{align}
#  Pr(\boldsymbol\phi|\{\mathbf{x}_{i},\mathbf{y}_{i}\}) &=& \text{Norm}_{\boldsymbol\phi}\biggl[\frac{1}{\sigma^2}\left(\frac{1}{\sigma^2}\mathbf{H}\mathbf{H}^T+\frac{1}{\sigma_p^2}\mathbf{I}\right)^{-1}\mathbf{H}\mathbf{y},\left(\frac{1}{\sigma^2}\mathbf{H}\mathbf{H}^T+\frac{1}{\sigma_p^2}\mathbf{I}\right)^{-1}\biggr].
# \end{align}
#
# TODO -- On a piece of paper, use the relations in Appendix C.3.3 and C.3.4 to fill in the missing steps and establish that this is the correct formula for the posterior.

# %% [markdown]
# <div style="color:green">
#
# First of all LHS of eq 1 should be $\prod_{i=1}^I Pr(y_i | x_i, \phi)$ and not $\prod_{i=1}^I Pr(y_i | x_i, phi + \beta)$. Since each of the output elements $y_i = (w^T h_i + \beta) + \epsilon, \  \epsilon \sim \mathcal{N}(0, \sigma^2 I)$, where $w^T h_i + \beta$ is of a linear form, we can apply the change of variable identity from section C.3.4 in the book because the mean of the multivariate normal is of the form $\omega h_i + \beta \implies Ay + b$. Moreover, $H$ needs to be transposed $H^T$ first before using the relation, because that's how the weights and biases are applied in the formula and because of the way the author defined H it needs this transformation to align with the function $f(x, \phi)$. Therefore in the C.3.4 we make these substitutions $A = H^T, b=0, (x-b) = y$ and simplify. To simplify away the covariance matrix, there are a few insights needed:
# 1. Whenever a diagonal matrix is multiplied by a vector it's equivalent to an elementwise multiplication between the diagonal elements of the diagonal matrix and the elements in the vector, we therefore have $\Sigma^{-1} v = (\sigma^{-1}_1, \dots, \sigma^{-1}_d) \cdot v$
# 2. Inverse of a diagonal matrix is the diagonal elements inverted.
# 3. If the diagonal elements of the diagonal covariance matrix are the same denoted as $\sigma^2$ then we have $\sigma^{-1} \cdot v = \frac{1}{\sigma^2} v$, so we can just factor out the diagonal elements as a constant factor.
#
# With this we have a straightforward simplifcation using the relation C.3.4:
#
# $$
# \begin{align}
# \prod_{i=1}^I Pr(y_i | x_i, \phi)
# &= \mathcal{N}_y [H^T \phi, \sigma^2] \\
# &\propto \mathcal{N}_{\phi}[(H \Sigma^{-1} H^T)^{-1} H \Sigma^{-1} y, (H \Sigma^{-1} H^T)^{-1}] \\
# &= \mathcal{N}_{\phi}[\sigma^2(H H^T)^{-1} H \frac{1}{\sigma^2} y, \sigma^2 (H H^T)^{-1}] \\
# &= \mathcal{N}_{\phi}[(H H^T)^{-1} H y, \sigma^2 (H H^T)^{-1}]
# \end{align}
# $$
#
# which is what the author got in eq 3. Moving on to applying relation C.3.3 is just straightforward, we set
#
# $$ a = (H H^T)^{-1} H y $$
# $$ A = \sigma^2(H H^T)^{-1}$$
# $$ b = 0 $$
# $$ B = \sigma^2_p I $$
#
# Now just plug these into the relation and we get
#
# $$
# \begin{align}
# Pr(\boldsymbol\phi|\{\mathbf{x}_{i},\mathbf{y}_{i}\})
# &\propto \prod_{i=1}^{I} Pr(\mathbf{y}_{i}|\mathbf{x}_{i},\boldsymbol\phi) Pr(\boldsymbol\phi) \\
# &\propto \mathcal{N}_{\boldsymbol\phi}\Bigl[\underbrace{(\mathbf{H}\mathbf{H}^T)^{-1}\mathbf{H}\mathbf{y}}_{=a},\underbrace{\sigma^2(\mathbf{H}\mathbf{H}^T)^{-1}}_{=A}\Bigr] \mathcal{N}_{\boldsymbol\phi}\Bigl[\underbrace{\mathbf{0}}_{=b},\underbrace{\sigma^2_p\mathbf{I}}_{=B}\Bigr] \\
# &\propto \mathcal{N}_{\phi}\Bigl[(A^{-1} + B^{-1})^{-1} (A^{-1}a + B^{-1}b), (A^{-1} + B^{-1})^{-1}\Bigr] \\
# &= \mathcal{N}_{\phi}\Bigl[(\frac{1}{\sigma^2} H H^T + \frac{1}{\sigma_p^2}I)^{-1} (\frac{1}{\sigma^2} \underbrace{H H^T (H H^T)^{-1}}_{=I} H y + B^{-1} \cdot 0), (\frac{1}{\sigma^2} H H^T + \frac{1}{\sigma_p^2}I)^{-1}\Bigr] \\
# &= \mathcal{N}_{\phi}\Bigl[\frac{1}{\sigma^2}(\frac{1}{\sigma^2} H H^T + \frac{1}{\sigma_p^2}I)^{-1} H y, (\frac{1}{\sigma^2} H H^T + \frac{1}{\sigma_p^2}I)^{-1}\Bigr] \\
# \end{align}
# $$
#
# which is what the author showed.
#
# </div>

# %%
def compute_H(x_data, n_hidden):
  psi1 = np.ones((n_hidden+1,1));
  psi0 = np.linspace(0.0, 1.0, num=n_hidden, endpoint=False) * -1

  n_data = x_data.size
  # First compute the hidden variables
  H = np.ones((n_hidden+1, n_data))
  for i in range(n_hidden):
    for j in range(n_data):
      # Compute preactivation
      H[i,j] = psi1[i] * x_data[j]+psi0[i]
      # Apply ReLU to get activation
      if H[i,j] < 0:
        H[i,j] = 0;

  return H

def compute_param_mean_covar(x_data, y_data, n_hidden, sigma_sq, sigma_p_sq):
  # Retrieve the matrix containing the hidden variables
  H = compute_H(x_data, n_hidden) ;

  # TODO -- Compute the covariance matrix (you will need np.transpose(), np.matmul(), np.linalg.inv())
  # Replace this line
  phi_covar = np.linalg.inv((1/sigma_sq) * np.dot(H, H.T) + (1 / sigma_p_sq) * np.identity(n_hidden+1))


  # TODO -- Compute the mean matrix
  # Replace this line
  phi_mean = (1/sigma_sq) * np.dot(np.linalg.inv((1/sigma_sq) * np.dot(H, H.T) + (1/sigma_p_sq) * np.identity(n_hidden + 1)), np.dot(H, y_data))


  return phi_mean, phi_covar

# %% [markdown]
# Now we can draw samples from this distribution

# %%
# Define parameters
n_hidden = 5
sigma_sq = sigma_func * sigma_func
# Arbitrary large value reflecting the fact we are uncertain about the
# parameters before we see any data
sigma_p_sq = 1000

# Compute the mean and covariance matrix
phi_mean, phi_covar = compute_param_mean_covar(x_data, y_data, n_hidden, sigma_sq, sigma_p_sq)

# Let's draw the mean model
x_model = x_func
y_model_mean = network(x_model, phi_mean[-1], phi_mean[0:n_hidden])
plot_function(x_func, y_func, x_data, y_data, x_model, y_model_mean)
# Out:
# C:\Users\harry\AppData\Local\Temp\ipykernel_10008\1892243779.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   H[i,j] = psi1[i] * x_data[j]+psi0[i]

# %%
# TODO Draw two samples from the normal distribution over the parameters
# Replace these lines
phi_sample1 = np.random.multivariate_normal(phi_mean, phi_covar);
phi_sample2 = np.random.multivariate_normal(phi_mean, phi_covar);


# Run the network for these two sample sets of parameters
y_model_sample1 = network(x_model, phi_sample1[-1], phi_sample1[0:n_hidden])
y_model_sample2 = network(x_model, phi_sample2[-1], phi_sample2[0:n_hidden])

# Draw the two models
plot_function(x_func, y_func, x_data, y_data, x_model, y_model_sample1)
plot_function(x_func, y_func, x_data, y_data, x_model, y_model_sample2)

# %% [markdown]
# Now we need to perform inference for a new data points $\mathbf{x}^*$ with corresponding hidden values $\mathbf{h}^*$.  Instead of having a single estimate of the parameters, we have a distribution over the possible parameters.  So we marginalize (integrate) over this distribution to account for all possible values:
#
# \begin{align}
# Pr(y^*|\mathbf{x}^*)  &= \int Pr(y^{*}|\mathbf{x}^*,\boldsymbol\phi)Pr(\boldsymbol\phi|\{\mathbf{x}_{i},\mathbf{y}_{i}\}) d\boldsymbol\phi\\
# &= \int \text{Norm}_{y^*}\bigl[[\mathbf{h}^{*T},1]\boldsymbol\phi,\sigma^2\bigr]\cdot\text{Norm}_{\boldsymbol\phi}\biggl[\frac{1}{\sigma^2}\left(\frac{1}{\sigma^2}\mathbf{H}\mathbf{H}^T+\frac{1}{\sigma_p^2}\mathbf{I}\right)^{-1}\mathbf{H}\mathbf{y},\left(\frac{1}{\sigma^2}\mathbf{H}\mathbf{H}^T+\frac{1}{\sigma_p^2}\mathbf{I}\right)^{-1}\biggr]d\boldsymbol\phi\\
# &= \text{Norm}_{y^*}\biggl[\frac{1}{\sigma^2} [\mathbf{h}^{*T},1]\left(\frac{1}{\sigma^2}\mathbf{H}\mathbf{H}^T+\frac{1}{\sigma_p^2}\mathbf{I}\right)^{-1}\mathbf{H}\mathbf{y},  [\mathbf{h}^{*T},1]\left(\frac{1}{\sigma^2}\mathbf{H}\mathbf{H}^T+\frac{1}{\sigma_p^2}\mathbf{I}\right)^{-1}
# [\mathbf{h}^*;1]\biggr],
# \end{align}
#
# where the notation $[\mathbf{h}^{*T},1]$ is a row vector containing $\mathbf{h}^{T}$ with a one appended to the end and $[\mathbf{h};1 ]$ is a column vector containing $\mathbf{h}$ with a one appended to the end.
#
#
# To compute this, we reformulated the integrand using the relations from appendices C.3.3 and C.3.4 as the product of a normal distribution in $\boldsymbol\phi$ and a constant with respect
# to $\boldsymbol\phi$. The integral of the normal distribution must be one, and so the final result is just the constant. This constant is itself a normal distribution in $y^*$. <br>
#
# If you feel so inclined you can work through the math of this yourself.

# %%
# Predict mean and variance of y_star from x_star
def inference(x_star, x_data, y_data, sigma_sq, sigma_p_sq, n_hidden):

  # Compute hidden variables
  h_star = compute_H(x_star, n_hidden); # size (6,1)
  #h_star = np.vstack((h_star, [[1]]))
  H = compute_H(x_data, n_hidden); # size (6,15)
  

  # TODO: Compute mean and variance of y*
  # Replace these lines:
  y_star_mean = (1/sigma_sq) * np.dot(h_star.T, np.dot(np.linalg.inv((1/sigma_sq) * np.dot(H, H.T) + (1 / sigma_p_sq) * np.identity(n_hidden+1)), np.dot(H, y_data)))
  y_star_var = np.dot(h_star.T, np.dot(np.linalg.inv((1/sigma_sq) * np.dot(H, H.T) + (1 / sigma_p_sq) * np.identity(n_hidden+1)), h_star))

  return y_star_mean, y_star_var

# %%
x_model = x_func
y_model = np.zeros_like(x_model)
y_model_std = np.zeros_like(x_model)
for c_model in range(len(x_model)):
  y_star_mean, y_star_var = inference(x_model[c_model]*np.ones((1,1)), x_data, y_data, sigma_sq, sigma_p_sq, n_hidden)
  y_model[c_model] = y_star_mean
  y_model_std[c_model] = np.sqrt(y_star_var)

# Draw the model
plot_function(x_func, y_func, x_data, y_data, x_model, y_model, sigma_model=y_model_std)
# Out:
# C:\Users\harry\AppData\Local\Temp\ipykernel_10008\1892243779.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   H[i,j] = psi1[i] * x_data[j]+psi0[i]
# C:\Users\harry\AppData\Local\Temp\ipykernel_10008\3005900570.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_model[c_model] = y_star_mean
# C:\Users\harry\AppData\Local\Temp\ipykernel_10008\3005900570.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_model_std[c_model] = np.sqrt(y_star_var)

# %% [markdown]
# TODO:
#
# 1.  Experiment running this again with different numbers of hidden units.  Make a prediction for what will happen when you increase / decrease them.
# 2.  Experiment with what happens if you make the prior variance $\sigma^2_p$ to a smaller value like 1.  How do you explain the results?

# %% [markdown]
# <div style="color:green">
#
# 1. More hidden nodes means more capacity, so that model will overfit more to the data. Lesser nodes means dumber model, so higher bias but lower variance in prediction.
# 2. For the uncertainty, changing the variance, is interesting if one is aware of the interpretation of L2 regularization using mean squared as error loss being equivalent to MAP bayesian inference with gaussian prior weight, which we have in our case. Look at the Typst document for context chapter 7. One can show that we can write the mean squared L2 regularization as $$\underset{w}{\operatorname{\text{argmin}}} \frac{1}{N} \sum_{i=1}^{N} (y_i - f(w; x_i, y_i))^2 + \frac{\lambda}{2 \sigma_w^2} w^T w$$
#
# If the variance factor is dropped, then we would get the familiar explicit L2-regularization. If we keep the variance factor in addition to the regularization strength term factor we can instead influence the weight penalty $w^T w$. This means that if
# - variance for the prior term is high then higher uncertainty and therefore more flexibility since the regularization strength will be scaled down.
# - variance for the prior term is low then lower uncertainty and therefore more regularization leading to smoother predictions.
#
# </div>

# %%
x_model = x_func
y_model = np.zeros_like(x_model)
y_model_std = np.zeros_like(x_model)
n_hidden = 1
sigma_p_sq = 1000
for c_model in range(len(x_model)):
  y_star_mean, y_star_var = inference(x_model[c_model]*np.ones((1,1)), x_data, y_data, sigma_sq, sigma_p_sq, n_hidden)
  y_model[c_model] = y_star_mean
  y_model_std[c_model] = np.sqrt(y_star_var)

# Draw the model
plot_function(x_func, y_func, x_data, y_data, x_model, y_model, sigma_model=y_model_std)
# Out:
# C:\Users\harry\AppData\Local\Temp\ipykernel_10008\1892243779.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   H[i,j] = psi1[i] * x_data[j]+psi0[i]
# C:\Users\harry\AppData\Local\Temp\ipykernel_10008\3974232521.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_model[c_model] = y_star_mean
# C:\Users\harry\AppData\Local\Temp\ipykernel_10008\3974232521.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_model_std[c_model] = np.sqrt(y_star_var)

# %%
x_model = x_func
y_model = np.zeros_like(x_model)
y_model_std = np.zeros_like(x_model)
n_hidden = 100
sigma_p_sq = 1000
for c_model in range(len(x_model)):
  y_star_mean, y_star_var = inference(x_model[c_model]*np.ones((1,1)), x_data, y_data, sigma_sq, sigma_p_sq, n_hidden)
  y_model[c_model] = y_star_mean
  y_model_std[c_model] = np.sqrt(y_star_var)

# Draw the model
plot_function(x_func, y_func, x_data, y_data, x_model, y_model, sigma_model=y_model_std)
# Out:
# C:\Users\harry\AppData\Local\Temp\ipykernel_10008\1892243779.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   H[i,j] = psi1[i] * x_data[j]+psi0[i]
# C:\Users\harry\AppData\Local\Temp\ipykernel_10008\3613997839.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_model[c_model] = y_star_mean
# C:\Users\harry\AppData\Local\Temp\ipykernel_10008\3613997839.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_model_std[c_model] = np.sqrt(y_star_var)

# %%
x_model = x_func
y_model = np.zeros_like(x_model)
y_model_std = np.zeros_like(x_model)
n_hidden = 5
sigma_p_sq = 100
for c_model in range(len(x_model)):
  y_star_mean, y_star_var = inference(x_model[c_model]*np.ones((1,1)), x_data, y_data, sigma_sq, sigma_p_sq, n_hidden)
  y_model[c_model] = y_star_mean
  y_model_std[c_model] = np.sqrt(y_star_var)

# Draw the model
plot_function(x_func, y_func, x_data, y_data, x_model, y_model, sigma_model=y_model_std)
# Out:
# C:\Users\harry\AppData\Local\Temp\ipykernel_10008\1892243779.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   H[i,j] = psi1[i] * x_data[j]+psi0[i]
# C:\Users\harry\AppData\Local\Temp\ipykernel_10008\3570212711.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_model[c_model] = y_star_mean
# C:\Users\harry\AppData\Local\Temp\ipykernel_10008\3570212711.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_model_std[c_model] = np.sqrt(y_star_var)

# %%
x_model = x_func
y_model = np.zeros_like(x_model)
y_model_std = np.zeros_like(x_model)
n_hidden = 100
sigma_p_sq = 1
for c_model in range(len(x_model)):
  y_star_mean, y_star_var = inference(x_model[c_model]*np.ones((1,1)), x_data, y_data, sigma_sq, sigma_p_sq, n_hidden)
  y_model[c_model] = y_star_mean
  y_model_std[c_model] = np.sqrt(y_star_var)

# Draw the model
plot_function(x_func, y_func, x_data, y_data, x_model, y_model, sigma_model=y_model_std)
# Out:
# C:\Users\harry\AppData\Local\Temp\ipykernel_10008\1892243779.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   H[i,j] = psi1[i] * x_data[j]+psi0[i]
# C:\Users\harry\AppData\Local\Temp\ipykernel_10008\3452661551.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_model[c_model] = y_star_mean
# C:\Users\harry\AppData\Local\Temp\ipykernel_10008\3452661551.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_model_std[c_model] = np.sqrt(y_star_var)
